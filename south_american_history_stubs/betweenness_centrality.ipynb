# %%
import csv
import json
import networkx as nx
edges = {}

with open('graph.csv', newline='') as graph_csv_file:
    reader = csv.DictReader(graph_csv_file)
    for row in reader:
        edges[row['node']] = json.loads(row['edges_within_category'])['key']
        edges[row['node']].extend(json.loads(row['edges_outside_category'])['key'])

# %%
G = nx.DiGraph()

# %%
for source_article, target_articles in edges.items():
    for target_article in target_articles:
        G.add_edge(source_article, target_article)

# %%
betweenness_centrality = nx.betweenness_centrality(G)

# %%
centrality_values = list(betweenness_centrality.values())

# %%
import numpy as np
mean_centrality = np.mean(centrality_values)
median_centrality = np.median(centrality_values)
max_centrality = np.max(centrality_values)
min_centrality = np.min(centrality_values)
std_centrality = np.std(centrality_values)


print(f"Mean Centrality: {mean_centrality}")
print(f"Median Centrality: {median_centrality}")
print(f"Max Centrality: {max_centrality}")
print(f"Min Centrality: {min_centrality}")
print(f"Standard Deviation of Centrality: {std_centrality}")
# Out:
# Mean Centrality: 0.00014806724087547524
# Median Centrality: 5.395313424728606e-06
# Max Centrality: 0.053242622223059206
# Min Centrality: 0.0
# Standard Deviation of Centrality: 0.0010246212990612006

# %%
import matplotlib.pyplot as plt
scaling_factor = 10000  # You can adjust this scaling factor as needed
scaled_betweenness = {article: centrality * scaling_factor for article, centrality in betweenness_centrality.items()}

# Plot the distribution of scaled betweenness centrality
plt.hist(scaled_betweenness.values(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Scaled Betweenness Centrality')
plt.ylabel('Frequency')
plt.title('Distribution of Scaled Betweenness Centrality')
plt.xlim(0, 100)
plt.grid(True)
plt.show()

# %%
sorted_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
top_50_pairs = sorted_centrality[:50]
for i, (article, centrality) in enumerate(top_50_pairs, 1):
    print(f"{i}. Article: {article}, Betweenness Centrality: {centrality}")
# Out:
# 1. Article: Brazil, Betweenness Centrality: 0.053242622223059206
# 2. Article: Peru, Betweenness Centrality: 0.04306244574809175
# 3. Article: Argentina, Betweenness Centrality: 0.03890668119256319
# 4. Article: Chile, Betweenness Centrality: 0.0341058116610783
# 5. Article: Timeline of Brazilian history, Betweenness Centrality: 0.025452338351372214
# 6. Article: Uruguay, Betweenness Centrality: 0.023142513646146196
# 7. Article: Lima, Betweenness Centrality: 0.018615375194354303
# 8. Article: Fauna of Uruguay, Betweenness Centrality: 0.014950260394181517
# 9. Article: List of wars involving Chile, Betweenness Centrality: 0.014247128032611548
# 10. Article: Colombia, Betweenness Centrality: 0.012803174008244685
# 11. Article: Paraguayan War, Betweenness Centrality: 0.01266849453953356
# 12. Article: Empire of Brazil, Betweenness Centrality: 0.012123410609236654
# 13. Article: Venezuela, Betweenness Centrality: 0.011591587330146688
# 14. Article: South America, Betweenness Centrality: 0.011242838691821135
# 15. Article: Latin America, Betweenness Centrality: 0.010926683256068812
# 16. Article: Rio de Janeiro, Betweenness Centrality: 0.010808837679837273
# 17. Article: Paraguay, Betweenness Centrality: 0.010063682784388926
# 18. Article: List of wars involving Brazil, Betweenness Centrality: 0.00894551514505678
# 19. Article: Meridiosaurus, Betweenness Centrality: 0.008700448733640651
# 20. Article: History of Brazil, Betweenness Centrality: 0.008669666646388137
# 21. Article: History of Chile, Betweenness Centrality: 0.008493978198020878
# 22. Article: History of Peru, Betweenness Centrality: 0.008017974365720305
# 23. Article: Montevideo, Betweenness Centrality: 0.008009093142825014
# 24. Article: Bolivia, Betweenness Centrality: 0.007600079471661123
# 25. Article: Machete, Betweenness Centrality: 0.00753944247852128
# 26. Article: Soviet Union, Betweenness Centrality: 0.007435196802256807
# 27. Article: Portuguese Empire, Betweenness Centrality: 0.007153238549605132
# 28. Article: Quechua people, Betweenness Centrality: 0.00688909071885805
# 29. Article: Uruguaysuchus, Betweenness Centrality: 0.006878328375256918
# 30. Article: History of Uruguay, Betweenness Centrality: 0.00677595055601748
# 31. Article: Ecuador, Betweenness Centrality: 0.006714782409057374
# 32. Article: Spanish Empire, Betweenness Centrality: 0.006647447667009692
# 33. Article: Portuguese people, Betweenness Centrality: 0.006078253911691109
# 34. Article: Coronelism, Betweenness Centrality: 0.005836885158094231
# 35. Article: Joaquim Nabuco, Betweenness Centrality: 0.005805172725259753
# 36. Article: South American, Betweenness Centrality: 0.005446545941572745
# 37. Article: History of Argentina, Betweenness Centrality: 0.005390570999279235
# 38. Article: Real Audiencia of Cusco, Betweenness Centrality: 0.005286546992606451
# 39. Article: Atlantic slave trade, Betweenness Centrality: 0.005174258505014232
# 40. Article: Pedro II of Brazil, Betweenness Centrality: 0.00515485382935638
# 41. Article: Rio Grande do Sul, Betweenness Centrality: 0.004971499981093367
# 42. Article: Viceroyalty of Peru, Betweenness Centrality: 0.004924333199232906
# 43. Article: Conquistador, Betweenness Centrality: 0.004808082270766307
# 44. Article: Jair Bolsonaro, Betweenness Centrality: 0.004781758219551866
# 45. Article: Machu Picchu, Betweenness Centrality: 0.004739235747986919
# 46. Article: Romani people, Betweenness Centrality: 0.00462719790521952
# 47. Article: Cusco, Betweenness Centrality: 0.004548719977119516
# 48. Article: List of years in Argentina, Betweenness Centrality: 0.004496159821862322
# 49. Article: Elections in Brazil, Betweenness Centrality: 0.004363325923764259
# 50. Article: Air France Flight 447, Betweenness Centrality: 0.0043442628548435785
